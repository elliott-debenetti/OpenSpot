# %% [markdown]
# # Environment

# %%
import os
os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = '1'
import io
import requests
import zipfile
import torch

# %%
# set device (current configured for Mac silicon devices)
if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")

# %%
# import dataset, models, and training utils.
from dataset import acpds
from utils.engine import train_model
from models.rcnn import RCNN

# %%
# load dataset
train_ds, valid_ds, test_ds = acpds.create_datasets('dataset/data')

# %%
model = RCNN()
train_model(model, train_ds, valid_ds, test_ds, model_dir = f'/out_dir//RCNN_v2', device, verbose=True, epochs=15)
# Out:
# /Users/elliott/miniforge3/envs/ucal/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/elliott/miniforge3/envs/ucal/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# epoch   1 -- train acc: 0.9050 -- valid acc.: 0.9612 -- 166 sec
# epoch   2 -- train acc: 0.9628 -- valid acc.: 0.9806 -- 158 sec
# epoch   3 -- train acc: 0.9639 -- valid acc.: 0.9752 -- 158 sec
# epoch   4 -- train acc: 0.9721 -- valid acc.: 0.9827 -- 163 sec
# epoch   5 -- train acc: 0.9757 -- valid acc.: 0.9781 -- 164 sec
# epoch   6 -- train acc: 0.9783 -- valid acc.: 0.9860 -- 164 sec
# epoch   7 -- train acc: 0.9809 -- valid acc.: 0.9839 -- 160 sec
# epoch   8 -- train acc: 0.9809 -- valid acc.: 0.9880 -- 166 sec
# epoch   9 -- train acc: 0.9802 -- valid acc.: 0.9550 -- 166 sec
# epoch  10 -- train acc: 0.9850 -- valid acc.: 0.9901 -- 165 sec
# epoch  11 -- train acc: 0.9869 -- valid acc.: 0.9868 -- 164 sec
# epoch  12 -- train acc: 0.9834 -- valid acc.: 0.9868 -- 165 sec
# epoch  13 -- train acc: 0.9894 -- valid acc.: 0.9880 -- 167 sec
# epoch  14 -- train acc: 0.9903 -- valid acc.: 0.9889 -- 165 sec
# epoch  15 -- train acc: 0.9881 -- valid acc.: 0.9897 -- 167 sec
